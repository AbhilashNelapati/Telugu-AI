# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhilashNelapati/Telugu-AI/blob/main/live_demo_for_asr_and_tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# !pip install pydub
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.6 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=0c4d413ca65fe3cc690eb1905ea7b637a866a5d0278cad7e507dbff9511a71ca
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
# ...

# %%
# !pip install gtts

# %%
# !pip install sounddevice

# %%
# !apt-get update
# !apt-get install libportaudio2
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [962 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,145 kB]
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# !pip install wavio

# %%
import streamlit as st
from googletrans import Translator
from gtts import gTTS
import torch
from transformers import pipeline
from pydub import AudioSegment
import numpy as np
from scipy.io import wavfile
from io import BytesIO

# %%
# Import the Audio class from IPython.display
from IPython.display import Audio

# %%
import sounddevice as sd
import numpy as np
import wavio
import io

# %%
def record_audio():
    fs = 44100  # Sampling frequency
    duration = 10  # Duration of recording in seconds
    silence_limit = 10  # Silence limit in seconds
    audio_data = []

    def callback(indata, frames, time, status):
        if status:
            print(status, flush=True)
        if np.any(indata):
            audio_data.append(indata.copy())

    with sd.InputStream(samplerate=fs, channels=1, callback=callback):
        print("Recording...")
        sd.sleep(duration * 1000)
        print("Recording stopped.")

    if not audio_data:
        return None

    audio_data = np.concatenate(audio_data, axis=0)
    audio_buffer = io.BytesIO()
    wavio.write(audio_buffer, audio_data, fs, sampwidth=2)
    audio_buffer.seek(0)
    return audio_buffer.read()

# %%
 # Title for the Streamlit app
st.title("Telugu ASR and Translation App")
# ASR Section
audio = "/content/Konda Reddy Love explained.mp3"
device = "cuda:0" if torch.cuda.is_available() else "cpu"
model_name = "vasista22/whisper-telugu-base"

transcribe = pipeline(
    task="automatic-speech-recognition",
    model=model_name,
    chunk_length_s=30,
    device=device
)
# Out:
# 2024-09-03 04:37:50.492 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 04:37:50.864
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-09-03 04:37:50.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
transcribe.model.config.forced_decoder_ids = transcribe.tokenizer.get_decoder_prompt_ids(language="te", task="transcribe")
transcription = transcribe(audio)["text"]





# Display ASR Output (Transcription) in Streamlit
st.write('ASR Output (Transcription): ', transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# 2024-09-03 05:04:39.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 05:04:39.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 05:04:39.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 05:04:39.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
print('ASR Output (Transcription): ', transcription)
# Out:
# ASR Output (Transcription):  తిరుమల వెంకటేశ్వర ఆలయం ప్రపంచంలో అత్యధికంగా సందర్శించే పుణ్యక్షేత్రాలలో ఒకటి

# %%
# TTS Section
tts = gTTS(text=transcription, lang='te')
output_file_te = "translated_output.mp3"
tts.save(output_file_te)


#diplay the telugu audio
display(Audio(output_file_te, autoplay=True)    )

# Provide audio playback in Streamlit
st.audio(output_file_te, format='audio/mp3')
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 2024-08-28 09:58:02.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:58:02.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:58:02.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Translate Telugu text to English
translator = Translator()
translated = translator.translate(transcription, src='te', dest='en')
translated_text = translated.text

# Display Translated Text in Streamlit
st.write('Translated Text: ', translated_text)


print('Translated Text: ', translated_text)
# Out:
# 2024-08-28 09:58:14.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:58:14.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:58:14.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:58:14.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Translated Text:  Thirumala Venkateswara Temple is one of the most visited shrines in the world

# %%
# TTS Section
tts = gTTS(text=translated_text, lang='en')
output_file_en = "translated_output.mp3"
tts.save(output_file_en)

      # Provide audio playback in Streamlit
st.audio(output_file_en, format='audio/mp3')
# Out:
# 2024-08-28 09:59:53.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:59:53.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 09:59:53.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
display(Audio(output_file_en, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install pyngrok

# %%
import streamlit as st
from googletrans import Translator
from gtts import gTTS
import torch
from transformers import pipeline
from pydub import AudioSegment
import numpy as np
from scipy.io import wavfile
from io import BytesIO

# Title for the Streamlit app
st.title("Telugu ASR and Translation App")

def record_audio():
    fs = 44100  # Sampling frequency
    duration = 10  # Duration of recording in seconds
    silence_limit = 10  # Silence limit in seconds
    audio_data = []

    def callback(indata, frames, time, status):
        if status:
            print(status, flush=True)
        if np.any(indata):
            audio_data.append(indata.copy())

    with sd.InputStream(samplerate=fs, channels=1, callback=callback):
        print("Recording...")
        sd.sleep(duration * 1000)
        print("Recording stopped.")

    if not audio_data:
        return None

    audio_data = np.concatenate(audio_data, axis=0)
    audio_buffer = io.BytesIO()
    wavio.write(audio_buffer, audio_data, fs, sampwidth=2)
    audio_buffer.seek(0)
    return audio_buffer.read()



# Call the record_audio function to get the audio data
audio_data = record_audio()

# Check if audio data was recorded successfully
if audio_data:
    transcribe.model.config.forced_decoder_ids = transcribe.tokenizer.get_decoder_prompt_ids(language="te", task="transcribe")
    transcription = transcribe(audio_data)["text"]

    # ... (rest of the code remains the same)
else:
    st.write("No audio recorded.")




# Display ASR Output (Transcription) in Streamlit
st.write('ASR Output (Transcription): ', transcription)
print('ASR Output (Transcription): ', transcription)



# TTS Section
tts = gTTS(text=transcription, lang='te')
output_file_te = "translated_output.mp3"
tts.save(output_file_te)


#diplay the telugu audio
display(Audio(output_file_te, autoplay=True)    )

# Provide audio playback in Streamlit
st.audio(output_file_te, format='audio/mp3')



# Translate Telugu text to English
translator = Translator()
translated = translator.translate(transcription, src='te', dest='en')
translated_text = translated.text

# Display Translated Text in Streamlit
st.write('Translated Text: ', translated_text)


print('Translated Text: ', translated_text)



# TTS Section
tts = gTTS(text=translated_text, lang='en')
output_file_en = "translated_output.mp3"
tts.save(output_file_en)

      # Provide audio playback in Streamlit
st.audio(output_file_en, format='audio/mp3')
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# <ipython-input-67-01ecce42a5ae> in <cell line: 43>()
#      41
#      42 # Call the record_audio function to get the audio data
# ---> 43 audio_data = record_audio()
#      44
#      45 # Check if audio data was recorded successfully
#
# <ipython-input-67-01ecce42a5ae> in record_audio()
#      24             audio_data.append(indata.copy())
#      25
# ---> 26     with sd.InputStream(samplerate=fs, channels=1, callback=callback):
#      27         print("Recording...")
#      28         sd.sleep(duration * 1000)
#
# /usr/local/lib/python3.10/dist-packages/sounddevice.py in __init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1427
#    1428         """
# ...

# %%
display(Audio(output_file_en, autoplay=True)    )
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Write the Streamlit app code to app.py
with open('app.py', 'w') as f:
    f.write("""
import streamlit as st
from googletrans import Translator
from gtts import gTTS
import torch
from transformers import pipeline
from pydub import AudioSegment
import numpy as np
from scipy.io import wavfile
from io import BytesIO

# Import the Audio class from IPython.display
from IPython.display import Audio

# Title for the Streamlit app
st.title("Telugu ASR and Translation App")
# ASR Section
audio = "/content/output.mp3"
device = "cuda:0" if torch.cuda.is_available() else "cpu"
model_name = "vasista22/whisper-telugu-base"

transcribe = pipeline(
    task="automatic-speech-recognition",
    model=model_name,
    chunk_length_s=30,
    device=device
)



transcribe.model.config.forced_decoder_ids = transcribe.tokenizer.get_decoder_prompt_ids(language="te", task="transcribe")
transcription = transcribe(audio)["text"]





# Display ASR Output (Transcription) in Streamlit
st.write('ASR Output (Transcription): ', transcription)
print('ASR Output (Transcription): ', transcription)



# TTS Section
tts = gTTS(text=transcription, lang='te')
output_file_te = "translated_output.mp3"
tts.save(output_file_te)


#diplay the telugu audio

# Provide audio playback in Streamlit
st.audio(output_file_te, format='audio/mp3')



# Translate Telugu text to English
translator = Translator()
translated = translator.translate(transcription, src='te', dest='en')
translated_text = translated.text

# Display Translated Text in Streamlit
st.write('Translated Text: ', translated_text)


print('Translated Text: ', translated_text)



# TTS Section
tts = gTTS(text=translated_text, lang='en')
output_file_en = "translated_output.mp3"
tts.save(output_file_en)

      # Provide audio playback in Streamlit
st.audio(output_file_en, format='audio/mp3')
""")

# %%
from pyngrok import ngrok
ngrok.kill()

ngrok.set_auth_token('2l36GHPzQA57Es3ZClMPExpmQDn_2Zqbji19LLTb9wTW6BVT9')

# Check for existing tunnels and disconnect if necessary
tunnels = ngrok.get_tunnels()
if tunnels:
    for tunnel in tunnels:
        print("Disconnecting existing tunnel:", tunnel.public_url)
        ngrok.disconnect(tunnel.public_url)

# %%
# Run the Streamlit app
import subprocess

# Run the Streamlit app
subprocess.Popen(['streamlit', 'run', 'app.py'])
# Out:
# <Popen: returncode: None args: ['streamlit', 'run', 'app.py']>

# %%
# Set up the ngrok tunnel
tunnel = ngrok.connect(8501, "http")  # Use ngrok.connect with port and protocol
public_url = tunnel.public_url
print('Streamlit app available at:', public_url)
# Out:
# Streamlit app available at: https://b3d2-35-233-243-197.ngrok-free.app
